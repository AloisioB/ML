# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
application = pd.read_csv("application_record.csv")
pagamentos = pd.read_csv("modulo19data.csv")

# %%
application.head(2)
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
#
#   NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 0  Rented apartment      -12005          -4542           1                1
# 1  Rented apartment      -12005          -4542           1                1
#
#    FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 0           0           0             NaN              2.0
# 1           0           0             NaN              2.0

# %%
pagamentos["STATUS"]
# Out:
# 0        BOM
# 1        BOM
# 2        BOM
# 3        BOM
# 4        BOM
#         ...
# 16645    BOM
# 16646    BOM
# 16647    BOM
# 16648    BOM
# 16649    MAU
# Name: STATUS, Length: 16650, dtype: object

# %%
pagamentos["STATUS"] = pagamentos["STATUS"].replace({"BOM" : 1, "MAU": 0})
pagamento = pagamentos[["ID", "STATUS"]].copy()

# %%
application = pd.merge(application, pagamento, on="ID", how="inner")

# %%
application
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      5008806           M            Y               Y             0
# 1      5008810           F            N               Y             0
# 2      5008811           F            N               Y             0
# 3      5112956           M            Y               Y             0
# 4      5008825           F            Y               N             0
# ...        ...         ...          ...             ...           ...
# 16645  5149042           F            N               Y             0
# 16646  5149056           F            N               Y             0
# 16647  5149145           M            Y               Y             0
# 16648  5149158           M            Y               Y             0
# 16649  5149838           F            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0              112500.0               Working  Secondary / secondary special
# 1              270000.0  Commercial associate  Secondary / secondary special
# 2              270000.0  Commercial associate  Secondary / secondary special
# 3              270000.0               Working               Higher education
# 4              130500.0               Working              Incomplete higher
# ...                 ...                   ...                            ...
# 16645          180000.0               Working  Secondary / secondary special
# 16646          112500.0  Commercial associate  Secondary / secondary special
# 16647          247500.0               Working  Secondary / secondary special
# 16648          247500.0               Working  Secondary / secondary special
# 16649          157500.0             Pensioner               Higher education
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0                   Married  House / apartment      -21474          -1134
# 1      Single / not married  House / apartment      -19110          -3051
# 2      Single / not married  House / apartment      -19110          -3051
# 3                   Married  House / apartment      -16872           -769
# 4                   Married  House / apartment      -10669          -1103
# ...                     ...                ...         ...            ...
# 16645        Civil marriage  House / apartment      -19750          -3608
# 16646               Married  House / apartment      -15837          -2694
# 16647               Married  House / apartment      -10952          -3577
# 16648               Married  House / apartment      -10952          -3577
# 16649               Married  House / apartment      -12387          -1325
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0               1                0           0           0  Security staff
# 1               1                0           1           1     Sales staff
# 2               1                0           1           1     Sales staff
# 3               1                1           1           1     Accountants
# 4               1                0           0           0     Accountants
# ...           ...              ...         ...         ...             ...
# 16645           1                0           0           0        Laborers
# 16646           1                1           1           0             NaN
# 16647           1                1           0           0        Laborers
# 16648           1                1           0           0        Laborers
# 16649           1                0           1           1  Medicine staff
#
#        CNT_FAM_MEMBERS  STATUS
# 0                  2.0       1
# 1                  1.0       1
# 2                  1.0       1
# 3                  2.0       1
# 4                  2.0       1
# ...                ...     ...
# 16645              2.0       1
# 16646              2.0       1
# 16647              2.0       1
# 16648              2.0       1
# 16649              2.0       0
#
# [16650 rows x 19 columns]

# %%
application.drop(columns="FLAG_MOBIL", inplace=True)

# %%
application["CODE_GENDER"] = application["CODE_GENDER"].replace({"M": 0, "F": 1}).astype("int16")
application["FLAG_OWN_CAR"] = application["FLAG_OWN_CAR"].replace({"N": 0, "Y": 1}).astype("int16")
application["FLAG_OWN_REALTY"] = application["FLAG_OWN_REALTY"].replace({"N": 0, "Y": 1}).astype("int16")
application["FLAG_WORK_PHONE"] = application["FLAG_WORK_PHONE"].replace({"N": 0, "Y": 1}).astype("int16")
application["FLAG_PHONE"] = application["FLAG_PHONE"].replace({"N": 0, "Y": 1}).astype("int16")
application["FLAG_EMAIL"] = application["FLAG_EMAIL"].replace({"N": 0, "Y": 1}).astype("int16")

# %%
application.dropna(inplace=True, subset=["FLAG_EMAIL", "FLAG_PHONE", "FLAG_WORK_PHONE"])

# %%
application.nunique()
# Out:
# ID                     16650
# CODE_GENDER                2
# FLAG_OWN_CAR               2
# FLAG_OWN_REALTY            2
# CNT_CHILDREN               8
# AMT_INCOME_TOTAL         221
# NAME_INCOME_TYPE           5
# NAME_EDUCATION_TYPE        5
# NAME_FAMILY_STATUS         5
# NAME_HOUSING_TYPE          6
# DAYS_BIRTH              5298
# DAYS_EMPLOYED           3005
# FLAG_WORK_PHONE            2
# FLAG_PHONE                 2
# FLAG_EMAIL                 2
# OCCUPATION_TYPE           18
# CNT_FAM_MEMBERS            9
# STATUS                     2
# dtype: int64

# %%
application.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16650 entries, 0 to 16649
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   16650 non-null  int64
#  1   CODE_GENDER          16650 non-null  int16
#  2   FLAG_OWN_CAR         16650 non-null  int16
#  3   FLAG_OWN_REALTY      16650 non-null  int16
#  4   CNT_CHILDREN         16650 non-null  int64
#  5   AMT_INCOME_TOTAL     16650 non-null  float64
#  6   NAME_INCOME_TYPE     16650 non-null  object
#  7   NAME_EDUCATION_TYPE  16650 non-null  object
#  8   NAME_FAMILY_STATUS   16650 non-null  object
#  9   NAME_HOUSING_TYPE    16650 non-null  object
#  10  DAYS_BIRTH           16650 non-null  int64
#  11  DAYS_EMPLOYED        16650 non-null  int64
#  12  FLAG_WORK_PHONE      16650 non-null  int16
#  13  FLAG_PHONE           16650 non-null  int16
#  14  FLAG_EMAIL           16650 non-null  int16
#  15  OCCUPATION_TYPE      11405 non-null  object
#  16  CNT_FAM_MEMBERS      16650 non-null  float64
#  17  STATUS               16650 non-null  int64
# dtypes: float64(2), int16(6), int64(5), object(5)
# memory usage: 1.8+ MB

# %%
application[["NAME_INCOME_TYPE", "NAME_EDUCATION_TYPE", "NAME_FAMILY_STATUS", "NAME_HOUSING_TYPE"]]
# Out:
#            NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0                   Working  Secondary / secondary special
# 1      Commercial associate  Secondary / secondary special
# 2      Commercial associate  Secondary / secondary special
# 3                   Working               Higher education
# 4                   Working              Incomplete higher
# ...                     ...                            ...
# 16645               Working  Secondary / secondary special
# 16646  Commercial associate  Secondary / secondary special
# 16647               Working  Secondary / secondary special
# 16648               Working  Secondary / secondary special
# 16649             Pensioner               Higher education
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE
# 0                   Married  House / apartment
# 1      Single / not married  House / apartment
# 2      Single / not married  House / apartment
# 3                   Married  House / apartment
# 4                   Married  House / apartment
# ...                     ...                ...
# 16645        Civil marriage  House / apartment
# 16646               Married  House / apartment
# 16647               Married  House / apartment
# 16648               Married  House / apartment
# 16649               Married  House / apartment
#
# [16650 rows x 4 columns]

# %%
dummies = pd.get_dummies(data=application,
               columns=["NAME_INCOME_TYPE", "NAME_EDUCATION_TYPE", "NAME_FAMILY_STATUS", "NAME_HOUSING_TYPE"],
               dtype="int16")

# %%
dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16650 entries, 0 to 16649
# Data columns (total 35 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 16650 non-null  int64
#  1   CODE_GENDER                                        16650 non-null  int16
#  2   FLAG_OWN_CAR                                       16650 non-null  int16
#  3   FLAG_OWN_REALTY                                    16650 non-null  int16
#  4   CNT_CHILDREN                                       16650 non-null  int64
#  5   AMT_INCOME_TOTAL                                   16650 non-null  float64
#  6   DAYS_BIRTH                                         16650 non-null  int64
#  7   DAYS_EMPLOYED                                      16650 non-null  int64
#  8   FLAG_WORK_PHONE                                    16650 non-null  int16
#  9   FLAG_PHONE                                         16650 non-null  int16
#  10  FLAG_EMAIL                                         16650 non-null  int16
#  11  OCCUPATION_TYPE                                    11405 non-null  object
#  12  CNT_FAM_MEMBERS                                    16650 non-null  float64
#  13  STATUS                                             16650 non-null  int64
#  14  NAME_INCOME_TYPE_Commercial associate              16650 non-null  int16
#  15  NAME_INCOME_TYPE_Pensioner                         16650 non-null  int16
#  16  NAME_INCOME_TYPE_State servant                     16650 non-null  int16
#  17  NAME_INCOME_TYPE_Student                           16650 non-null  int16
#  18  NAME_INCOME_TYPE_Working                           16650 non-null  int16
#  19  NAME_EDUCATION_TYPE_Academic degree                16650 non-null  int16
#  20  NAME_EDUCATION_TYPE_Higher education               16650 non-null  int16
#  21  NAME_EDUCATION_TYPE_Incomplete higher              16650 non-null  int16
#  22  NAME_EDUCATION_TYPE_Lower secondary                16650 non-null  int16
#  23  NAME_EDUCATION_TYPE_Secondary / secondary special  16650 non-null  int16
#  24  NAME_FAMILY_STATUS_Civil marriage                  16650 non-null  int16
#  25  NAME_FAMILY_STATUS_Married                         16650 non-null  int16
#  26  NAME_FAMILY_STATUS_Separated                       16650 non-null  int16
#  27  NAME_FAMILY_STATUS_Single / not married            16650 non-null  int16
#  28  NAME_FAMILY_STATUS_Widow                           16650 non-null  int16
#  29  NAME_HOUSING_TYPE_Co-op apartment                  16650 non-null  int16
#  30  NAME_HOUSING_TYPE_House / apartment                16650 non-null  int16
#  31  NAME_HOUSING_TYPE_Municipal apartment              16650 non-null  int16
#  32  NAME_HOUSING_TYPE_Office apartment                 16650 non-null  int16
#  33  NAME_HOUSING_TYPE_Rented apartment                 16650 non-null  int16
#  34  NAME_HOUSING_TYPE_With parents                     16650 non-null  int16
# dtypes: float64(2), int16(27), int64(5), object(1)
# memory usage: 2.0+ MB

# %%
dummies.drop(columns="OCCUPATION_TYPE", inplace=True)

# %%
dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16650 entries, 0 to 16649
# Data columns (total 34 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   ID                                                 16650 non-null  int64
#  1   CODE_GENDER                                        16650 non-null  int16
#  2   FLAG_OWN_CAR                                       16650 non-null  int16
#  3   FLAG_OWN_REALTY                                    16650 non-null  int16
#  4   CNT_CHILDREN                                       16650 non-null  int64
#  5   AMT_INCOME_TOTAL                                   16650 non-null  float64
#  6   DAYS_BIRTH                                         16650 non-null  int64
#  7   DAYS_EMPLOYED                                      16650 non-null  int64
#  8   FLAG_WORK_PHONE                                    16650 non-null  int16
#  9   FLAG_PHONE                                         16650 non-null  int16
#  10  FLAG_EMAIL                                         16650 non-null  int16
#  11  CNT_FAM_MEMBERS                                    16650 non-null  float64
#  12  STATUS                                             16650 non-null  int64
#  13  NAME_INCOME_TYPE_Commercial associate              16650 non-null  int16
#  14  NAME_INCOME_TYPE_Pensioner                         16650 non-null  int16
#  15  NAME_INCOME_TYPE_State servant                     16650 non-null  int16
#  16  NAME_INCOME_TYPE_Student                           16650 non-null  int16
#  17  NAME_INCOME_TYPE_Working                           16650 non-null  int16
#  18  NAME_EDUCATION_TYPE_Academic degree                16650 non-null  int16
#  19  NAME_EDUCATION_TYPE_Higher education               16650 non-null  int16
#  20  NAME_EDUCATION_TYPE_Incomplete higher              16650 non-null  int16
#  21  NAME_EDUCATION_TYPE_Lower secondary                16650 non-null  int16
#  22  NAME_EDUCATION_TYPE_Secondary / secondary special  16650 non-null  int16
#  23  NAME_FAMILY_STATUS_Civil marriage                  16650 non-null  int16
#  24  NAME_FAMILY_STATUS_Married                         16650 non-null  int16
#  25  NAME_FAMILY_STATUS_Separated                       16650 non-null  int16
#  26  NAME_FAMILY_STATUS_Single / not married            16650 non-null  int16
#  27  NAME_FAMILY_STATUS_Widow                           16650 non-null  int16
#  28  NAME_HOUSING_TYPE_Co-op apartment                  16650 non-null  int16
#  29  NAME_HOUSING_TYPE_House / apartment                16650 non-null  int16
#  30  NAME_HOUSING_TYPE_Municipal apartment              16650 non-null  int16
#  31  NAME_HOUSING_TYPE_Office apartment                 16650 non-null  int16
#  32  NAME_HOUSING_TYPE_Rented apartment                 16650 non-null  int16
#  33  NAME_HOUSING_TYPE_With parents                     16650 non-null  int16
# dtypes: float64(2), int16(27), int64(5)
# memory usage: 1.9 MB

# %%
dummies_sample = dummies.sample(10000)
dummies_sample
# Out:
#             ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2884   5029096            0             1                1             2
# 3612   5036340            1             1                1             0
# 11025  5096790            1             0                1             0
# 8991   5087824            0             0                1             2
# 81     5009053            1             0                1             2
# ...        ...          ...           ...              ...           ...
# 15892  5148609            1             1                1             0
# 16366  5149945            1             0                1             0
# 10501  5093252            1             0                1             0
# 2639   5028514            1             1                1             0
# 3034   5029502            1             0                1             0
#
#        AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_WORK_PHONE  \
# 2884           135000.0      -11564          -2944                0
# 3612           225000.0      -19949         365243                0
# 11025           67500.0      -20371         365243                0
# 8991           112500.0      -15788          -1563                0
# 81             202500.0      -10997          -2289                0
# ...                 ...         ...            ...              ...
# 15892          135000.0      -22800         365243                0
# 16366          180000.0      -22228           -686                1
# 10501          247500.0      -11914          -2980                0
# 2639           225000.0      -19724         -12591                0
# 3034            67500.0      -12281          -1508                0
#
#        FLAG_PHONE  ...  NAME_FAMILY_STATUS_Married  \
# 2884            0  ...                           1
# 3612            0  ...                           1
# 11025           0  ...                           1
# 8991            0  ...                           1
# 81              0  ...                           1
# ...           ...  ...                         ...
# 15892           0  ...                           1
# 16366           1  ...                           1
# 10501           0  ...                           1
# 2639            0  ...                           1
# 3034            0  ...                           1
#
#        NAME_FAMILY_STATUS_Separated  NAME_FAMILY_STATUS_Single / not married  \
# 2884                              0                                        0
# 3612                              0                                        0
# 11025                             0                                        0
# 8991                              0                                        0
# 81                                0                                        0
# ...                             ...                                      ...
# 15892                             0                                        0
# 16366                             0                                        0
# 10501                             0                                        0
# 2639                              0                                        0
# 3034                              0                                        0
#
#        NAME_FAMILY_STATUS_Widow  NAME_HOUSING_TYPE_Co-op apartment  \
# 2884                          0                                  0
# 3612                          0                                  0
# 11025                         0                                  0
# 8991                          0                                  0
# 81                            0                                  0
# ...                         ...                                ...
# 15892                         0                                  0
# 16366                         0                                  0
# 10501                         0                                  0
# 2639                          0                                  0
# 3034                          0                                  0
#
#        NAME_HOUSING_TYPE_House / apartment  \
# 2884                                     1
# 3612                                     1
# 11025                                    1
# 8991                                     1
# 81                                       1
# ...                                    ...
# 15892                                    1
# 16366                                    1
# 10501                                    1
# 2639                                     1
# 3034                                     1
#
#        NAME_HOUSING_TYPE_Municipal apartment  \
# 2884                                       0
# 3612                                       0
# 11025                                      0
# 8991                                       0
# 81                                         0
# ...                                      ...
# 15892                                      0
# 16366                                      0
# 10501                                      0
# 2639                                       0
# 3034                                       0
#
#        NAME_HOUSING_TYPE_Office apartment  NAME_HOUSING_TYPE_Rented apartment  \
# 2884                                    0                                   0
# 3612                                    0                                   0
# 11025                                   0                                   0
# 8991                                    0                                   0
# 81                                      0                                   0
# ...                                   ...                                 ...
# 15892                                   0                                   0
# 16366                                   0                                   0
# 10501                                   0                                   0
# 2639                                    0                                   0
# 3034                                    0                                   0
#
#        NAME_HOUSING_TYPE_With parents
# 2884                                0
# 3612                                0
# 11025                               0
# 8991                                0
# 81                                  0
# ...                               ...
# 15892                               0
# 16366                               0
# 10501                               0
# 2639                                0
# 3034                                0
#
# [10000 rows x 34 columns]

# %%
y = dummies_sample.loc[:, "STATUS"]
x = dummies_sample.loc[:, ~dummies_sample.columns.isin(["STATUS"])]
dummies_sample["STATUS"].isna().sum()
# Out:
# 0

# %%
#selected_columns = dummies2.columns[dummies2.columns != "STATUS"]
#selected_columns

# %%
clf = DecisionTreeClassifier(max_depth=6)

# %%
x.columns
# Out:
# Index(['ID', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN',
#        'AMT_INCOME_TOTAL', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'FLAG_WORK_PHONE',
#        'FLAG_PHONE', 'FLAG_EMAIL', 'CNT_FAM_MEMBERS',
#        'NAME_INCOME_TYPE_Commercial associate', 'NAME_INCOME_TYPE_Pensioner',
#        'NAME_INCOME_TYPE_State servant', 'NAME_INCOME_TYPE_Student',
#        'NAME_INCOME_TYPE_Working', 'NAME_EDUCATION_TYPE_Academic degree',
#        'NAME_EDUCATION_TYPE_Higher education',
#        'NAME_EDUCATION_TYPE_Incomplete higher',
#        'NAME_EDUCATION_TYPE_Lower secondary',
#        'NAME_EDUCATION_TYPE_Secondary / secondary special',
#        'NAME_FAMILY_STATUS_Civil marriage', 'NAME_FAMILY_STATUS_Married',
#        'NAME_FAMILY_STATUS_Separated',
#        'NAME_FAMILY_STATUS_Single / not married', 'NAME_FAMILY_STATUS_Widow',
#        'NAME_HOUSING_TYPE_Co-op apartment',
#        'NAME_HOUSING_TYPE_House / apartment',
#        'NAME_HOUSING_TYPE_Municipal apartment',
#        'NAME_HOUSING_TYPE_Office apartment',
#        'NAME_HOUSING_TYPE_Rented apartment', 'NAME_HOUSING_TYPE_With parents'],
#       dtype='object')

# %%
clf.fit(X=x.values, y=y.values)
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
plt.figure(figsize=(20, 25))
plot_tree(clf, filled=True)
# Out:
# [Text(0.5481770833333334, 0.9285714285714286, 'x[7] <= -1161.5\ngini = 0.023\nsamples = 10000\nvalue = [118, 9882]'),
#  Text(0.3359375, 0.7857142857142857, 'x[13] <= 0.5\ngini = 0.015\nsamples = 6193\nvalue = [47, 6146]'),
#  Text(0.2552083333333333, 0.6428571428571429, 'x[16] <= 0.5\ngini = 0.015\nsamples = 6190\nvalue = [46, 6144]'),
#  Text(0.15625, 0.5, 'x[4] <= 3.5\ngini = 0.023\nsamples = 2367\nvalue = [27, 2340]'),
#  Text(0.08333333333333333, 0.35714285714285715, 'x[0] <= 5038796.0\ngini = 0.022\nsamples = 2360\nvalue = [26, 2334]'),
#  Text(0.041666666666666664, 0.21428571428571427, 'x[24] <= 0.5\ngini = 0.004\nsamples = 548\nvalue = [1, 547]'),
#  Text(0.020833333333333332, 0.07142857142857142, 'gini = 0.0\nsamples = 512\nvalue = [0, 512]'),
#  Text(0.0625, 0.07142857142857142, 'gini = 0.054\nsamples = 36\nvalue = [1, 35]'),
#  Text(0.125, 0.21428571428571427, 'x[0] <= 5038825.0\ngini = 0.027\nsamples = 1812\nvalue = [25, 1787]'),
#  Text(0.10416666666666667, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14583333333333334, 0.07142857142857142, 'gini = 0.026\nsamples = 1811\nvalue = [24, 1787]'),
#  Text(0.22916666666666666, 0.35714285714285715, 'x[0] <= 5116258.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.20833333333333334, 0.21428571428571427, 'x[3] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1875, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.22916666666666666, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.25, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3541666666666667, 0.5, 'x[5] <= 156375.0\ngini = 0.01\nsamples = 3823\nvalue = [19, 3804]'),
#  Text(0.3125, 0.35714285714285715, 'x[6] <= -18958.0\ngini = 0.002\nsamples = 1619\nvalue = [2, 1617]'),
#  Text(0.2916666666666667, 0.21428571428571427, 'x[6] <= -18977.5\ngini = 0.014\nsamples = 274\nvalue = [2, 272]'),
#  Text(0.2708333333333333, 0.07142857142857142, 'gini = 0.007\nsamples = 273\nvalue = [1, 272]'),
#  Text(0.3125, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3333333333333333, 0.21428571428571427, 'gini = 0.0\nsamples = 1345\nvalue = [0, 1345]'),
#  Text(0.3958333333333333, 0.35714285714285715, 'x[0] <= 5096743.5\ngini = 0.015\nsamples = 2204\nvalue = [17, 2187]'),
#  Text(0.375, 0.21428571428571427, 'x[0] <= 5096712.0\ngini = 0.023\nsamples = 1461\nvalue = [17, 1444]'),
#  Text(0.3541666666666667, 0.07142857142857142, 'gini = 0.022\nsamples = 1460\nvalue = [16, 1444]'),
#  Text(0.3958333333333333, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4166666666666667, 0.21428571428571427, 'gini = 0.0\nsamples = 743\nvalue = [0, 743]'),
#  Text(0.4166666666666667, 0.6428571428571429, 'x[5] <= 202500.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3958333333333333, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4375, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7604166666666666, 0.7857142857142857, 'x[6] <= -10758.5\ngini = 0.037\nsamples = 3807\nvalue = [71, 3736]'),
#  Text(0.65625, 0.6428571428571429, 'x[27] <= 0.5\ngini = 0.03\nsamples = 3435\nvalue = [53, 3382]'),
#  Text(0.5833333333333334, 0.5, 'x[24] <= 0.5\ngini = 0.029\nsamples = 3423\nvalue = [51, 3372]'),
#  Text(0.5, 0.35714285714285715, 'x[7] <= -1160.5\ngini = 0.025\nsamples = 3218\nvalue = [41, 3177]'),
#  Text(0.4583333333333333, 0.21428571428571427, 'x[11] <= 2.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.4375, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4791666666666667, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5416666666666666, 0.21428571428571427, 'x[29] <= 0.5\ngini = 0.025\nsamples = 3214\nvalue = [40, 3174]'),
#  Text(0.5208333333333334, 0.07142857142857142, 'gini = 0.022\nsamples = 3107\nvalue = [34, 3073]'),
#  Text(0.5625, 0.07142857142857142, 'gini = 0.106\nsamples = 107\nvalue = [6, 101]'),
#  Text(0.6666666666666666, 0.35714285714285715, 'x[6] <= -24112.5\ngini = 0.093\nsamples = 205\nvalue = [10, 195]'),
#  Text(0.625, 0.21428571428571427, 'x[6] <= -24790.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6041666666666666, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6458333333333334, 0.07142857142857142, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7083333333333334, 0.21428571428571427, 'x[6] <= -14062.0\ngini = 0.058\nsamples = 200\nvalue = [6, 194]'),
#  Text(0.6875, 0.07142857142857142, 'gini = 0.012\nsamples = 163\nvalue = [1, 162]'),
#  Text(0.7291666666666666, 0.07142857142857142, 'gini = 0.234\nsamples = 37\nvalue = [5, 32]'),
#  Text(0.7291666666666666, 0.5, 'x[26] <= 0.5\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.7083333333333334, 0.35714285714285715, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.75, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8645833333333334, 0.6428571428571429, 'x[5] <= 387000.0\ngini = 0.092\nsamples = 372\nvalue = [18, 354]'),
#  Text(0.8125, 0.5, 'x[6] <= -10753.0\ngini = 0.074\nsamples = 363\nvalue = [14, 349]'),
#  Text(0.7916666666666666, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8333333333333334, 0.35714285714285715, 'x[11] <= 3.5\ngini = 0.069\nsamples = 362\nvalue = [13, 349]'),
#  Text(0.7916666666666666, 0.21428571428571427, 'x[5] <= 312750.0\ngini = 0.056\nsamples = 347\nvalue = [10, 337]'),
#  Text(0.7708333333333334, 0.07142857142857142, 'gini = 0.042\nsamples = 330\nvalue = [7, 323]'),
#  Text(0.8125, 0.07142857142857142, 'gini = 0.291\nsamples = 17\nvalue = [3, 14]'),
#  Text(0.875, 0.21428571428571427, 'x[19] <= 0.5\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.8541666666666666, 0.07142857142857142, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.8958333333333334, 0.07142857142857142, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9166666666666666, 0.5, 'x[2] <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.8958333333333334, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9375, 0.35714285714285715, 'x[0] <= 5120087.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.9166666666666666, 0.21428571428571427, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9583333333333334, 0.21428571428571427, 'x[0] <= 5149188.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9375, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9791666666666666, 0.07142857142857142, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]')]

# %%
w = dummies_sample.loc[:, ~dummies_sample.columns.isin(["STATUS"])]
w
# Out:
#             ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2884   5029096            0             1                1             2
# 3612   5036340            1             1                1             0
# 11025  5096790            1             0                1             0
# 8991   5087824            0             0                1             2
# 81     5009053            1             0                1             2
# ...        ...          ...           ...              ...           ...
# 15892  5148609            1             1                1             0
# 16366  5149945            1             0                1             0
# 10501  5093252            1             0                1             0
# 2639   5028514            1             1                1             0
# 3034   5029502            1             0                1             0
#
#        AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_WORK_PHONE  \
# 2884           135000.0      -11564          -2944                0
# 3612           225000.0      -19949         365243                0
# 11025           67500.0      -20371         365243                0
# 8991           112500.0      -15788          -1563                0
# 81             202500.0      -10997          -2289                0
# ...                 ...         ...            ...              ...
# 15892          135000.0      -22800         365243                0
# 16366          180000.0      -22228           -686                1
# 10501          247500.0      -11914          -2980                0
# 2639           225000.0      -19724         -12591                0
# 3034            67500.0      -12281          -1508                0
#
#        FLAG_PHONE  ...  NAME_FAMILY_STATUS_Married  \
# 2884            0  ...                           1
# 3612            0  ...                           1
# 11025           0  ...                           1
# 8991            0  ...                           1
# 81              0  ...                           1
# ...           ...  ...                         ...
# 15892           0  ...                           1
# 16366           1  ...                           1
# 10501           0  ...                           1
# 2639            0  ...                           1
# 3034            0  ...                           1
#
#        NAME_FAMILY_STATUS_Separated  NAME_FAMILY_STATUS_Single / not married  \
# 2884                              0                                        0
# 3612                              0                                        0
# 11025                             0                                        0
# 8991                              0                                        0
# 81                                0                                        0
# ...                             ...                                      ...
# 15892                             0                                        0
# 16366                             0                                        0
# 10501                             0                                        0
# 2639                              0                                        0
# 3034                              0                                        0
#
#        NAME_FAMILY_STATUS_Widow  NAME_HOUSING_TYPE_Co-op apartment  \
# 2884                          0                                  0
# 3612                          0                                  0
# 11025                         0                                  0
# 8991                          0                                  0
# 81                            0                                  0
# ...                         ...                                ...
# 15892                         0                                  0
# 16366                         0                                  0
# 10501                         0                                  0
# 2639                          0                                  0
# 3034                          0                                  0
#
#        NAME_HOUSING_TYPE_House / apartment  \
# 2884                                     1
# 3612                                     1
# 11025                                    1
# 8991                                     1
# 81                                       1
# ...                                    ...
# 15892                                    1
# 16366                                    1
# 10501                                    1
# 2639                                     1
# 3034                                     1
#
#        NAME_HOUSING_TYPE_Municipal apartment  \
# 2884                                       0
# 3612                                       0
# 11025                                      0
# 8991                                       0
# 81                                         0
# ...                                      ...
# 15892                                      0
# 16366                                      0
# 10501                                      0
# 2639                                       0
# 3034                                       0
#
#        NAME_HOUSING_TYPE_Office apartment  NAME_HOUSING_TYPE_Rented apartment  \
# 2884                                    0                                   0
# 3612                                    0                                   0
# 11025                                   0                                   0
# 8991                                    0                                   0
# 81                                      0                                   0
# ...                                   ...                                 ...
# 15892                                   0                                   0
# 16366                                   0                                   0
# 10501                                   0                                   0
# 2639                                    0                                   0
# 3034                                    0                                   0
#
#        NAME_HOUSING_TYPE_With parents
# 2884                                0
# 3612                                0
# 11025                               0
# 8991                                0
# 81                                  0
# ...                               ...
# 15892                               0
# 16366                               0
# 10501                               0
# 2639                                0
# 3034                                0
#
# [10000 rows x 33 columns]

# %%
clf.predict(X=w.values)
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
right = 0
till = 5000

for i in range(till):
    w = dummies.loc[i, ~dummies.columns.isin(["STATUS"])]
    if clf.predict(X=[w.values]) == dummies.loc[i, "STATUS"]:
        right += 1

print(right/till)
# Out:
# 0.9956

# %%
dummies.to_csv("application_clean.csv")
